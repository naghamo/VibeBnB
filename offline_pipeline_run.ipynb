# %%
# !pip install reverse_geocoder

# %% [markdown]
# # Data Integration

# %%
python data/data_join.py

# %% [markdown]
# #Scoring

# %%
python score.py

# %% [markdown]
# # Embedding and ANN

# %%
python embeddings_fit.py
